# %% [markdown]
# Sure! Here's an explanation of each library:
#
# 1. **NumPy**: NumPy is a fundamental library for scientific computing in Python. It provides support for large, multi-dimensional arrays and matrices, along with a collection of mathematical functions to operate on these arrays. NumPy is widely used for numerical computations and data manipulation in various fields such as machine learning, data analysis, and scientific research.
#
# 2. **Pandas**: Pandas is a powerful library for data manipulation and analysis. It provides data structures like DataFrames and Series, which allow for efficient handling and processing of structured data. Pandas is commonly used for tasks such as data cleaning, data wrangling, data exploration, and data visualization.
#
# 3. **Seaborn**: Seaborn is a data visualization library built on top of Matplotlib. It provides a high-level interface for creating attractive and informative statistical graphics. Seaborn simplifies the process of creating various types of plots, such as scatter plots, line plots, bar plots, histograms, and heatmaps. It also offers additional functionality for visualizing relationships between variables and exploring patterns in data.
#
# 4. **Matplotlib**: Matplotlib is a widely-used plotting library in Python. It provides a flexible and comprehensive set of functions for creating a wide range of static, animated, and interactive visualizations. Matplotlib can be used to create basic plots, customize plot appearance, add annotations, and create complex visualizations. It serves as the foundation for many other plotting libraries in Python, including Seaborn.
#
# .

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as mlt

# %% [markdown]
#  dataset.head(), you will see the first few rows of the dataset printed to the console

# %%
dataset = pd.read_csv("covid19_Confirmed_dataset.csv")
dataset.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %% [markdown]
#  "Lat" and "Long" from the dataset using the drop() function from the Pandas library. The axis=1 parameter specifies that the columns should be dropped along the horizontal axis (columns) rather than the vertical axis (rows). The inplace=True parameter ensures that the changes are made directly to the dataset, modifying it in place.

# %%
df = dataset.drop(["Lat", "Long"], axis=1, inplace=True)

# %% [markdown]
# *   drops the column "Province/State" from the dataset using the drop() function from the Pandas library. The axis=1 parameter specifies that the column should be dropped along the horizontal axis (columns) rather than the vertical axis (rows).
# * The inplace=True parameter ensures that the changes are made directly to the dataset, modifying it in place

# %%
df = dataset.drop(["Province/State"], axis=1, inplace=True)
dataset.head()
# Out:
#   Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0    Afghanistan        0        0        0        0        0        0
# 1        Albania        0        0        0        0        0        0
# 2        Algeria        0        0        0        0        0        0
# 3        Andorra        0        0        0        0        0        0
# 4         Angola        0        0        0        0        0        0
#
#    1/28/20  1/29/20  1/30/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# 0     1463     1531     1703     1828     1939     2171
# ...

# %% [markdown]
# *  The dataset by the "Country/Region" column using the groupby() function from the Pandas library.
# *   The groupby() function groups the rows of the dataset based on unique values in the specified column.

# %%
aggregated_dataset = dataset.groupby("Country/Region").sum()

# %% [markdown]
# *   aggregated_dataset.head() is used to display the first few rows of the
# aggregated_dataset DataFrame.
# *   The head() function in Pandas is used to retrieve the top rows of a DataFrame.

# %%
aggregated_dataset.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1092     1176     1279
# Albania               0        0        0  ...      609      634      663
# Algeria               0        0        0  ...     2811     2910     3007
# Andorra               0        0        0  ...      717      723      723
# ...

# %% [markdown]
# *   aggregated_dataset.shape is used to retrieve the shape of the aggregated_dataset DataFrame.
# * The shape attribute in Pandas returns a tuple representing the dimensions of the DataFrame, with the number of rows followed by the number of columns.

# %%
aggregated_dataset.shape
# Out:
# (187, 100)

# %% [markdown]
# * aggregated_dataset.loc["India"].plot() is used to plot a graph of the data  for the country "India" from the aggregated_dataset DataFrame.
#
#
# *   The loc indexer in Pandas is used to access a specific row or rows based on the label(s) provided.

# %%
aggregated_dataset.loc["India"].plot()
# Out:
# <Axes: >

# %% [markdown]
#  provided Plots the data for multiple countries from the aggregated_dataset DataFrame.

# %%
aggregated_dataset.loc["India"].plot()
aggregated_dataset.loc["Brazil"].plot()
aggregated_dataset.loc["Switzerland"].plot()
aggregated_dataset.loc["Pakistan"].plot()
aggregated_dataset.loc["Nepal"].plot()
mlt.legend()

# %%
aggregated_dataset.loc["India"].plot()
# Out:
# <Axes: >

# %% [markdown]
# *    aggregated_dataset.loc["India"][:5].plot() is used to plot the data for the country "India" from the aggregated_dataset DataFrame, specifically the first five rows of the data. The loc indexer is used to access the row corresponding to "India", and the [:5] indexing is used to select the first five rows of that data.
#
# *   plot() function is part of the Pandas library and allows you to visualize data using various types of plots, such as line plots, bar plots, or scatter plots.

# %%
aggregated_dataset.loc["India"][:5].plot()
# Out:
# <Axes: >

# %% [markdown]
# * aggregated_dataset.loc["India"].diff().plot() is used to plot the difference between consecutive values of the data for the country "India" from the aggregated_dataset DataFrame.
# *   The loc indexer is used to access the row corresponding to "India", and the diff() function is applied to calculate the difference between consecutive values.

# %%
aggregated_dataset.loc["India"].diff().plot()
# Out:
# <Axes: >

# %% [markdown]
# *   aggregated_dataset.loc["India"].diff().max() calculates the maximum
# difference between consecutive values in the data for the country "India" from the aggregated_dataset DataFrame.
# *  The loc indexer is used to access the row corresponding to "India", and the diff() function is applied to calculate the differences between consecutive values.
# * the max() function is used to find the maximum value among these differences.

# %%
aggregated_dataset.loc["India"].diff().max()
# Out:
# 1893.0

# %%
aggregated_dataset.loc["Pakistan"].diff().max()
# Out:
# 1292.0

# %%
aggregated_dataset.loc["Germany"].diff().max()
# Out:
# 6933.0

# %% [markdown]
# *   The resulting output will provide the count of null values in each column of the aggregated_dataset DataFrame. This  identifying missing data and deciding how to handle it, such as imputing missing values or excluding rows with missing data.
#
#
# *   The number of null values will depend on the structure and content of the aggregated_dataset DataFrame.
#
#
# *   The isnull() function is used to identify null values in a DataFrame, and the sum() function is used to calculate the sum of null values for each column

# %%
aggregated_dataset.isnull().sum()
# Out:
# 1/22/20    0
# 1/23/20    0
# 1/24/20    0
# 1/25/20    0
# 1/26/20    0
#           ..
# 4/26/20    0
# 4/27/20    0
# 4/28/20    0
# 4/29/20    0
# 4/30/20    0
# Length: 100, dtype: int64

# %% [markdown]
# *   countries = list(aggregated_dataset.index): This line retrieves the list of
# countries from the index of the aggregated_dataset DataFrame and assigns it to the variable countries.
# *  max_infection_rates = []: This line initializes an empty list called max_infection_rates to store the maximum infection rates for each country.
# for c in countries:: This line starts a loop that iterates over each country in the countries list.
#
#
#
#
# *   max_infection_rates.append(aggregated_dataset.loc[c].diff().max()): This line calculates the maximum infection rate for the current country c. It uses the loc indexer to access the data for the current country from the aggregated_dataset DataFrame.
# *   The diff() function is then applied to calculate the differences between consecutive values, and the max() function is used to find the maximum difference. The resulting maximum infection rate is appended to the max_infection_rates list.
#
#
#
#
#
# *   aggregated_dataset["Max_infection_rates"] = max_infection_rates: This line
# creates a new column called "Max_infection_rates" in the aggregated_dataset DataFrame and assigns the max_infection_rates list as its values. Each value in the list corresponds to the maximum infection rate for the respective country.

# %%
countries = list(aggregated_dataset.index)
max_infection_rates = []

for c in countries:
    max_infection_rates.append(aggregated_dataset.loc[c].diff().max())

aggregated_dataset["Max_infection_rates"] = max_infection_rates

# %% [markdown]
# * aggregated_dataset.head() is used to display the first few rows of the aggregated_dataset DataFrame. The head() function is applied to the DataFrame.

# %%
aggregated_dataset.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %% [markdown]
# *   corona_data = aggregated_dataset["Max_infection_rates"] creates a new variable called corona_data that stores the values from the "Max_infection_rates" column of the aggregated_dataset DataFrame.
#
# *  corona_data = aggregated_dataset["Max_infection_rates"]: This line selects the column "Max_infection_rates" from the aggregated_dataset DataFrame and assigns it to the variable corona_data. The resulting corona_data variable will contain the values from the "Max_infection_rates" column.
#
#
#
# *   corona_data.head(): This line displays the first few rows of the corona_data Series. The head() function is applied to the Series, which by default returns the first five rows.

# %%
corona_data = aggregated_dataset["Max_infection_rates"]
corona_data.head()
# Out:
# Country/Region
# Afghanistan    232.0
# Albania         34.0
# Algeria        199.0
# Andorra         43.0
# Angola           5.0
# Name: Max_infection_rates, dtype: float64

# %% [markdown]
# *   The shape of a DataFrame or Series in Python represents the dimensions or size of the data structure.
# *   In the case of corona_data.shape, it returns a tuple that represents the number of rows and columns in the corona_data Series.

# %%
corona_data.shape
# Out:
# (187,)

# %% [markdown]
# *  happiness_report = pd.read_csv("worldwide_happiness_report.csv") reads the data from a CSV file called "worldwide_happiness_report.csv" and assigns it to a variable named happiness_report.
#
#
#
#
# *  pd.read_csv("worldwide_happiness_report.csv"): This line uses the read_csv()
# function from the pandas library (pd) to read the data from the CSV file named "worldwide_happiness_report.csv". The function reads the file and returns a DataFrame containing the data.
#
# *  happiness_report = pd.read_csv("worldwide_happiness_report.csv"): This line assigns the DataFrame returned by pd.read_csv() to a variable named happiness_report. The variable happiness_report can then be used to access and manipulate the data from the CSV file.

# %%
happiness_report = pd.read_csv("worldwide_happiness_report.csv")

# %% [markdown]
#  happiness_report.head() is used to display the first few rows of the happiness_report DataFrame. The head() function is applied to the DataFrame, which by default returns the first five rows

# %%
happiness_report.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %% [markdown]
# *   useless_columns = happiness_report.drop(["Overall rank", "Score", "Generosity", "Perceptions of corruption"], axis=1, inplace=True) removes specific columns from the happiness_report DataFrame. The columns being dropped are "Overall rank", "Score", "Generosity", and "Perceptions of corruption".
#
# *  happiness_report.drop(["Overall rank", "Score", "Generosity", "Perceptions of corruption"], axis=1, inplace=True): This line uses the drop() function from the pandas library to remove the specified columns from the happiness_report DataFrame. The drop() function allows you to drop columns or rows from a DataFrame based on specified labels or indices. The axis=1 parameter indicates and inplace=True ensures that the changes are made directly to the happiness_report DataFrame.
#
# *  useless_columns = happiness_report.drop(["Overall rank", "Score", "Generosity", "Perceptions of corruption"], axis=1, inplace=True): This line assigns the modified DataFrame (after dropping the columns) to a new variable named useless_columns. The useless_columns variable will contain the updated DataFrame without the specified columns.

# %%
useless_columns = happiness_report.drop(["Overall rank", "Score", "Generosity", "Perceptions of corruption"], axis=1, inplace=True)

# %% [markdown]
# happiness_report.head() function is used to display the first few rows of a DataFrame

# %%
happiness_report.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %% [markdown]
# *   happiness_report.set_index("Country or region", inplace=True): This line uses the set_index() function to set the "Country or region" column as the new index of the happiness_report DataFrame.
# *  The set_index() function allows you to specify a column to be used as the index of the DataFrame. The inplace=True parameter ensures that the changes are made directly to the happiness_report DataFrame.

# %%
happiness_report.set_index("Country or region", inplace=True)
happiness_report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %% [markdown]
# *   the .shape attribute is used to retrieve the dimensions of a DataFrame or a NumPy array. It returns a tuple containing the number of rows and columns in the DataFrame.

# %%
corona_data.shape
# Out:
# (187,)

# %%
happiness_report.shape
# Out:
# (156, 4)

# %% [markdown]
# *   corona_data = pd.DataFrame(corona_data) converts the corona_data variable into a DataFrame using the pd.DataFrame() function from the pandas library. This assumes that corona_data was previously stored as a compatible data structure.
# *   The code data = corona_data.join(happiness_report, how="inner") performs an
# inner join between the corona_data DataFrame and the happiness_report DataFrame. The join() function is used to combine two DataFrames based on a common column or index.
# * corona_data = pd.DataFrame(corona_data): This line converts the corona_data variable into a DataFrame using the pd.DataFrame() function. This step is necessary if corona_data was previously stored in a different data structure.
#
# *  data = corona_data.join(happiness_report, how="inner"): This line performs an inner join between the corona_data DataFrame and the happiness_report DataFrame. The join() function is used to combine two DataFrames based on a common column or index. In this case, the join is performed using the default index of both DataFrames.

# %%
corona_data = pd.DataFrame(corona_data)
data = corona_data.join(happiness_report, how="inner")
data.head()
# Out:
#              Max_infection_rates  GDP per capita  Social support  \
# Afghanistan                232.0           0.350           0.517
# Albania                     34.0           0.947           0.848
# Algeria                    199.0           1.002           1.160
# Argentina                  291.0           1.092           1.432
# Armenia                    134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %% [markdown]
# data.corr() function calculates the correlation between columns in the data DataFrame.

# %%
data.corr()
# Out:
#                               Max_infection_rates  GDP per capita  \
# Max_infection_rates                      1.000000        0.250118
# GDP per capita                           0.250118        1.000000
# Social support                           0.191958        0.759468
# Healthy life expectancy                  0.289263        0.863062
# Freedom to make life choices             0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# Max_infection_rates                 0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# Max_infection_rates                               0.078196
# ...

# %%
data
# Out:
#              Max_infection_rates  GDP per capita  Social support  \
# Afghanistan                232.0           0.350           0.517
# Albania                     34.0           0.947           0.848
# Algeria                    199.0           1.002           1.160
# Argentina                  291.0           1.092           1.432
# Armenia                    134.0           0.850           1.055
# ...                          ...             ...             ...
# Venezuela                   29.0           0.960           1.427
# Vietnam                     19.0           0.741           1.346
# Yemen                        5.0           0.287           1.163
# Zambia                       9.0           0.578           1.058
# Zimbabwe                     8.0           0.366           1.114
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# ...

# %% [markdown]
# *  sns.scatterplot(data=data, x=x, y=np.log(y)) uses the seaborn library to create a scatter plot visualization. It plots the relationship between the "GDP per capita" column (x) and the logarithm of the "Max_infection_rates" column (y) from the data DataFrame.
#
#
#
# *   sns.scatterplot(): This function from the seaborn library is used to create a scatter plot.
#
#
# *   data=data: This parameter specifies the DataFrame (data) from which the data for the scatter plot will be taken.
# *  x=x: This parameter specifies the column (x) from the data DataFrame that will
# be plotted on the x-axis.
#
# *   y=np.log(y): This parameter specifies the column (y) from the data DataFrame that will be plotted on the y-axis. The np.log() function from the numpy library is used to calculate the logarithm of the values in the "Max_infection_rates" column.

# %% [markdown]
# *   "GDP per capita" values on the x-axis and the logarithm of "Max_infection_rates" values on the y-axis from the data DataFrame.

# %%
#visualisation
x = data["GDP per capita"]
y = data["Max_infection_rates"]
sns.scatterplot(data=data, x=x, y=np.log(y))
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Max_infection_rates'>

# %% [markdown]
# *   The code `sns.regplot(data=data, x=x, y=np.log(y))` uses the seaborn library to create a scatter plot with a regression line. It plots the relationship between the "GDP per capita" column (`x`) and the logarithm of the "Max_infection_rates" column (`y`) from the `data` DataFrame.
#
#
#
# 1. sns.regplot ():This function from the seaborn library is used to create a scatter plot with a regression line.
#
# 2. data-data(): This parameter specifies the DataFrame (`data`) from which the data for the scatter plot will be taken.
#
# 3. x=x(): This parameter specifies the column (`x`) from the `data` DataFrame that will be plotted on the x-axis.
#
# 4. y=np.logy(): This parameter specifies the column (`y`) from the `data` DataFrame that will be plotted on the y-axis. The `np.log()` function from the numpy library is used to calculate the logarithm of the values in the "Max_infection_rates" column. Taking the logarithm of the values can be useful when dealing with data that has a wide range of values or when trying to visualize exponential relationships.

# %%
sns.regplot(data = data,x=x,y=np.log(y))
# Out:
# <Axes: xlabel='GDP per capita', ylabel='Max_infection_rates'>

# %% [markdown]
# *   sns.scatterplot(): This function from the seaborn library is used to create a scatter plot.
#
#
# *   x=x: This parameter specifies the column (x) from the data DataFrame that will be plotted on the x-axis.
#
# *   y=np.log(y): This parameter specifies the column (y) from the data DataFrame that will be plotted on the y-axis. The np.log() function from the numpy library is used to calculate the logarithm of the values in the "Max_infection_rates" column. Taking the logarithm of the values can be useful when dealing with data that has a wide range of values or when trying to visualize exponential relationships.

# %%
x = data["Social support"]
y = data["Max_infection_rates"]

sns.scatterplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='Social support', ylabel='Max_infection_rates'>

# %% [markdown]
# *   sns.scatterplot(): This function from the seaborn library is used to create a scatter plot.
#
#
# *   x=x: This parameter specifies the column (x) from the data DataFrame that will be plotted on the x-axis. In this case, it is the "Social support" column.
#
# * y=np.log(y): This parameter specifies the column (y) from the data DataFrame that will be plotted on the y-axis. The np.log() function from the numpy library is used to calculate the logarithm of the values in the "Max_infection_rates" column. Taking the logarithm of the values can be useful when dealing with data that has a wide range of values or when trying to visualize exponential relationships.

# %%
sns.regplot(x=x, y=np.log(y))
# Out:
# <Axes: xlabel='Social support', ylabel='Max_infection_rates'>

# %%
x = data["Healthy life expectancy"]
y = data["Max_infection_rates"]

sns.scatterplot(x=x, y=np.log(y))
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='Max_infection_rates'>

# %%
sns.regplot(x=x, y=np.log(y))
# Out:
# <Axes: xlabel='Healthy life expectancy', ylabel='Max_infection_rates'>

# %% [markdown]
# *   sns.scatterplot(x=x, y=np.log(y)) uses the seaborn library to create a scatter plot visualization. It plots the relationship between the "Freedom to make life choices" column (x) and the logarithm of the "Max_infection_rates" column (y) from the data DataFrame.
#
# *   sns.scatterplot(): This function from the seaborn library is used to create a scatter plot.
#
# *  x=x: This parameter specifies the column (x) from the data DataFrame that will be plotted on the x-axis. In this case, it is the "Freedom to make life choices" column.
#
# *   y=np.log(y): This parameter specifies the column (y) from the data DataFrame that will be plotted on the y-axis. The np.log() function from the numpy library is used to calculate the logarithm of the values in the "Max_infection_rates" column. Taking the logarithm of the values can be useful when dealing with data that has a wide range of values or when trying to visualize exponential relationships.

# %% [markdown]
# *   sns.scatterplot(): This function from the seaborn library is used to create a scatter plot.
#
#
#
# *  x=x: This parameter specifies the column (x) from the data DataFrame that will be plotted on the x-axis. In this case, it is the "Freedom to make life choices" column.
# *  y=np.log(y): This parameter specifies the column (y) from the data DataFrame that will be plotted on the y-axis. The np.log() function from the numpy library is used to calculate the logarithm of the values in the
# *   "Max_infection_rates" column. Taking the logarithm of the values can be useful when dealing with data that has a wide range of values or when trying to visualize exponential relationships.

# %%
x = data["Freedom to make life choices"]
y = data["Max_infection_rates"]
sns.scatterplot(x=x, y=np.log(y))
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='Max_infection_rates'>

# %% [markdown]
# *   sns.regplot(): This function from the seaborn library is used to create a scatter plot with a regression line.
#
#
#
# *   x=x: This parameter specifies the column (x) from the data DataFrame that will be plotted on the x-axis. In this case, it is the "Freedom to make life choices" column.
#
#
# *   y=np.log(y): This parameter specifies the column (y) from the data DataFrame that will be plotted on the y-axis. The np.log() function from the numpy library is used to calculate the logarithm of the values in the "Max_infection_rates" column.

# %%
sns.regplot(x=x, y=np.log(y))
# Out:
# <Axes: xlabel='Freedom to make life choices', ylabel='Max_infection_rates'>

# %%
# So This Case Study conclude that we got positive regression line for Freedom to make life choices , GDP per capita , Healthy life expectancy,
# Social report with the Max_infection_rates of the complete dataframe or data given to us.
#THANK YOU
